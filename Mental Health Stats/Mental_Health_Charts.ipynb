# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the statistical dataset
stats_df = pd.read_csv('mental_health_data.csv')
stats_df.head(3)
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc DataSource          Topic  \
# 0       2018     2018           NV       Nevada      BRFSS  Mental Health
# 1       2020     2020           NV       Nevada      BRFSS  Mental Health
# 2       2018     2018           NV       Nevada      BRFSS  Mental Health
#
#                                             Question DataValueUnit  \
# 0  At least 14 recent mentally unhealthy days amo...             %
# 1  Recent mentally unhealthy days among adults ag...        Number
# 2  Recent mentally unhealthy days among adults ag...        Number
#
#       DataValueType  DataValue  ...  HighConfidenceLimit  \
# 0  Crude Prevalence       21.6  ...                 26.8
# 1              Mean        4.1  ...                  5.8
# 2              Mean        5.0  ...                  5.6
#
#   StratificationCategory1      Stratification1  \
# 0                 Overall              Overall
# 1          Race/Ethnicity  Black, non-Hispanic
# 2                  Gender               Female
#
#                                       GeoLocation LocationID TopicID  \
# 0  POINT (-117.07184056399967 39.493240390000494)         32     MTH
# 1  POINT (-117.07184056399967 39.493240390000494)         32     MTH
# 2  POINT (-117.07184056399967 39.493240390000494)         32     MTH
#
#   QuestionID  DataValueTypeID StratificationCategoryID1 StratificationID1
# 0     MTH2_0          CRDPREV                   OVERALL               OVR
# 1     MTH1_0             MEAN                      RACE               BLK
# 2     MTH1_0             MEAN                    GENDER              GENF
#
# [3 rows x 23 columns]

# %%
# Clean the DatatFrame by dropping unnecessary rows and columns
stats_df = stats_df.drop(columns = ["YearEnd", "Topic", "DataValueAlt", "DataSource", "DatavalueFootnote",
                                    "LocationID", "TopicID", "QuestionID", "DataValueTypeID",
                                   "StratificationCategoryID1", "StratificationID1"])
stats_df = stats_df.rename(columns = {"YearStart": "Year", "LocationAbbr": "StateAbbr", "LocationDesc": "State"})
stats_df = stats_df.dropna()

# %%
stats_df.head(3)
# Out:
#    Year StateAbbr   State                                           Question  \
# 0  2018        NV  Nevada  At least 14 recent mentally unhealthy days amo...
# 1  2020        NV  Nevada  Recent mentally unhealthy days among adults ag...
# 2  2018        NV  Nevada  Recent mentally unhealthy days among adults ag...
#
#   DataValueUnit     DataValueType  DataValue  LowConfidenceLimit  \
# 0             %  Crude Prevalence       21.6                17.2
# 1        Number              Mean        4.1                 2.4
# 2        Number              Mean        5.0                 4.4
#
#    HighConfidenceLimit StratificationCategory1      Stratification1  \
# 0                 26.8                 Overall              Overall
# 1                  5.8          Race/Ethnicity  Black, non-Hispanic
# 2                  5.6                  Gender               Female
#
#                                       GeoLocation
# 0  POINT (-117.07184056399967 39.493240390000494)
# 1  POINT (-117.07184056399967 39.493240390000494)
# 2  POINT (-117.07184056399967 39.493240390000494)

# %%
# Export updated stats Dataframe to CSV File
stats_df.to_csv("updated_mental_health_data.csv", index = False)

# %%
texas_df = stats_df[stats_df['State'] == 'Texas']
texas_df = texas_df.sort_values(by='Year')
texas_df = texas_df.reset_index(drop=True)
texas_df.head(3)
# Out:
#    Year StateAbbr  State                                           Question  \
# 0  2011        TX  Texas  Recent mentally unhealthy days among adults ag...
# 1  2011        TX  Texas  Recent mentally unhealthy days among adults ag...
# 2  2011        TX  Texas  At least 14 recent mentally unhealthy days amo...
#
#   DataValueUnit      DataValueType  DataValue  LowConfidenceLimit  \
# 0        Number  Age-adjusted Mean        2.8                 1.9
# 1        Number  Age-adjusted Mean        4.2                 3.9
# 2             %   Crude Prevalence       13.8                11.0
#
#    HighConfidenceLimit StratificationCategory1      Stratification1  \
# 0                  3.6          Race/Ethnicity  Other, non-Hispanic
# 1                  4.5                  Gender               Female
# 2                 17.1          Race/Ethnicity             Hispanic
#
#                                      GeoLocation
# 0  POINT (-99.42677020599967 31.827240407000488)
# 1  POINT (-99.42677020599967 31.827240407000488)
# 2  POINT (-99.42677020599967 31.827240407000488)

# %%
# Export texas_df to CSV File
texas_df.to_csv("texas_mental_health.csv", index = False)

# %%
# Calculate the average mentally unhealthy days for each state
avg_bad_days = stats_df.groupby("State")["DataValue"].mean() 

# Get the states from the index of the groupby result
states = avg_bad_days.index

# Plot the data
plt.figure(figsize=(20,4))
plt.xticks(rotation=90)
plt.bar(states, avg_bad_days)
plt.title("Average Recent Mentally Unhealthy Days by State (2011-2021)")
plt.show()

# %%
# Sort states by descending average recent mentally unhealthy days

# Calculate the average mentally unhealthy days for each state
avg_bad_days = stats_df.groupby("State")["DataValue"].mean()

# Sort the values descending
avg_bad_days = avg_bad_days.sort_values(ascending=False)  

# Get the states from the index of the groupby result
states = avg_bad_days.index

# Plot the data
plt.figure(figsize=(20,4))
plt.xticks(rotation=90)
plt.bar(states, avg_bad_days)
plt.title("Average Recent Mentally Unhealthy Days by State (2011-2021)")
plt.show()

# %%
# Calculate the average mentally unhealthy days for each state
avg_bad_days2 = stats_df.groupby("Year")["DataValue"].mean()

# Get the states from the index of the groupby result
states = avg_bad_days2.index

# Plot the data
plt.figure(figsize=(20,4))
plt.xticks(rotation=0)
plt.bar(states, avg_bad_days2)
plt.title("Average Recent Mentally Unhealthy Days for Adults (2011-2021)")
plt.show()

# %%
#Filter unhealthy days by race
question = stats_df[stats_df['Question'] == 'Recent mentally unhealthy days among adults aged >= 18 years']
race = question[question['StratificationCategory1'] == 'Race/Ethnicity']
race_df = race[['Year', 'State', 'Question', 'DataValueType', 'DataValue', 'Stratification1']]
race_df = race_df.rename(columns = {"Stratification1": "Race/Ethnicity"})
race_df = race_df.sort_values(by=['State', 'Year', 'Race/Ethnicity'])

# %%
# Use overall mean opposed to age-adjusted mean
race_df = race_df[race_df['DataValueType'] == 'Mean']
race_df = race_df.reset_index(drop=True)
race_df.head()
# Out:
#    Year    State                                           Question  \
# 0  2011  Alabama  Recent mentally unhealthy days among adults ag...
# 1  2011  Alabama  Recent mentally unhealthy days among adults ag...
# 2  2011  Alabama  Recent mentally unhealthy days among adults ag...
# 3  2011  Alabama  Recent mentally unhealthy days among adults ag...
# 4  2013  Alabama  Recent mentally unhealthy days among adults ag...
#
#   DataValueType  DataValue       Race/Ethnicity
# 0          Mean        5.0  Black, non-Hispanic
# 1          Mean        5.6             Hispanic
# 2          Mean        5.7  Other, non-Hispanic
# 3          Mean        4.6  White, non-Hispanic
# 4          Mean        4.4  Black, non-Hispanic

# %%
# Export race_df to CSV File
race_df.to_csv("race_ethnicity.csv", index = False)

# %%
#Filter unhealthy days by gender
question = stats_df[stats_df['Question'] == 'Recent mentally unhealthy days among adults aged >= 18 years']
gender = question[question['StratificationCategory1'] == 'Gender']
gender_df = gender[['Year', 'State', 'Question', 'DataValueType', 'DataValue', 'Stratification1']]
gender_df = gender_df.rename(columns = {"Stratification1": "Gender"})
gender_df = gender_df.sort_values(by=['State', 'Year', 'Gender'])

# %%
# Use overall mean opposed to age-adjusted mean
gender_df = gender_df[gender_df['DataValueType'] == 'Mean']
gender_df = gender_df.reset_index(drop=True)
gender_df
# Out:
#       Year    State                                           Question  \
# 0     2011  Alabama  Recent mentally unhealthy days among adults ag...
# 1     2011  Alabama  Recent mentally unhealthy days among adults ag...
# 2     2012  Alabama  Recent mentally unhealthy days among adults ag...
# 3     2012  Alabama  Recent mentally unhealthy days among adults ag...
# 4     2013  Alabama  Recent mentally unhealthy days among adults ag...
# ...    ...      ...                                                ...
# 1161  2019  Wyoming  Recent mentally unhealthy days among adults ag...
# 1162  2020  Wyoming  Recent mentally unhealthy days among adults ag...
# 1163  2020  Wyoming  Recent mentally unhealthy days among adults ag...
# 1164  2021  Wyoming  Recent mentally unhealthy days among adults ag...
# 1165  2021  Wyoming  Recent mentally unhealthy days among adults ag...
#
#      DataValueType  DataValue  Gender
# 0             Mean        5.5  Female
# 1             Mean        4.1    Male
# 2             Mean        5.9  Female
# 3             Mean        4.4    Male
# 4             Mean        5.3  Female
# ...            ...        ...     ...
# 1161          Mean        3.3    Male
# 1162          Mean        4.9  Female
# 1163          Mean        3.0    Male
# 1164          Mean        5.7  Female
# 1165          Mean        3.7    Male
#
# [1166 rows x 6 columns]

# %%
# Export to CSV File
gender_df.to_csv("gender.csv", index = False)

# %%
# Filter average number of unhealthy days by gender in 2020
year_2020_df = gender_df[gender_df['Year'] == 2020]
year_2020_df.head(10)
# Out:
#      Year       State                                           Question  \
# 18   2020     Alabama  Recent mentally unhealthy days among adults ag...
# 19   2020     Alabama  Recent mentally unhealthy days among adults ag...
# 40   2020      Alaska  Recent mentally unhealthy days among adults ag...
# 41   2020      Alaska  Recent mentally unhealthy days among adults ag...
# 62   2020     Arizona  Recent mentally unhealthy days among adults ag...
# 63   2020     Arizona  Recent mentally unhealthy days among adults ag...
# 84   2020    Arkansas  Recent mentally unhealthy days among adults ag...
# 85   2020    Arkansas  Recent mentally unhealthy days among adults ag...
# 106  2020  California  Recent mentally unhealthy days among adults ag...
# 107  2020  California  Recent mentally unhealthy days among adults ag...
#
#     DataValueType  DataValue  Gender
# 18           Mean        5.9  Female
# 19           Mean        3.8    Male
# 40           Mean        4.4  Female
# 41           Mean        2.4    Male
# 62           Mean        4.9  Female
# 63           Mean        3.5    Male
# 84           Mean        6.3  Female
# 85           Mean        4.1    Male
# 106          Mean        4.5  Female
# 107          Mean        3.6    Male

# %%
# Filter average number of unhealthy days by gender in 2020
race_2020_df = race_df[race_df['Year'] == 2020]
race_2020_df
# Out:
#       Year      State                                           Question  \
# 35    2020    Alabama  Recent mentally unhealthy days among adults ag...
# 36    2020    Alabama  Recent mentally unhealthy days among adults ag...
# 37    2020    Alabama  Recent mentally unhealthy days among adults ag...
# 38    2020    Alabama  Recent mentally unhealthy days among adults ag...
# 39    2020    Alabama  Recent mentally unhealthy days among adults ag...
# ...    ...        ...                                                ...
# 2306  2020  Wisconsin  Recent mentally unhealthy days among adults ag...
# 2337  2020    Wyoming  Recent mentally unhealthy days among adults ag...
# 2338  2020    Wyoming  Recent mentally unhealthy days among adults ag...
# 2339  2020    Wyoming  Recent mentally unhealthy days among adults ag...
# 2340  2020    Wyoming  Recent mentally unhealthy days among adults ag...
#
#      DataValueType  DataValue             Race/Ethnicity
# 35            Mean        5.3        Black, non-Hispanic
# 36            Mean        5.0                   Hispanic
# 37            Mean        5.1  Multiracial, non-Hispanic
# 38            Mean        5.8        Other, non-Hispanic
# 39            Mean        4.7        White, non-Hispanic
# ...            ...        ...                        ...
# 2306          Mean        4.0        White, non-Hispanic
# 2337          Mean        5.1                   Hispanic
# 2338          Mean        7.6  Multiracial, non-Hispanic
# 2339          Mean        5.9        Other, non-Hispanic
# 2340          Mean        3.7        White, non-Hispanic
#
# [244 rows x 6 columns]

# %%
# Filter average number of unhealthy days by gender in Texas
texas_gender_df = gender_df[gender_df['State'] == 'Texas']
texas_gender_df.head(10)
# Out:
#      Year  State                                           Question  \
# 986  2011  Texas  Recent mentally unhealthy days among adults ag...
# 987  2011  Texas  Recent mentally unhealthy days among adults ag...
# 988  2012  Texas  Recent mentally unhealthy days among adults ag...
# 989  2012  Texas  Recent mentally unhealthy days among adults ag...
# 990  2013  Texas  Recent mentally unhealthy days among adults ag...
# 991  2013  Texas  Recent mentally unhealthy days among adults ag...
# 992  2014  Texas  Recent mentally unhealthy days among adults ag...
# 993  2014  Texas  Recent mentally unhealthy days among adults ag...
# 994  2015  Texas  Recent mentally unhealthy days among adults ag...
# 995  2015  Texas  Recent mentally unhealthy days among adults ag...
#
#     DataValueType  DataValue  Gender
# 986          Mean        4.2  Female
# 987          Mean        2.9    Male
# 988          Mean        4.1  Female
# 989          Mean        3.2    Male
# 990          Mean        3.9  Female
# 991          Mean        2.5    Male
# 992          Mean        3.5  Female
# 993          Mean        2.5    Male
# 994          Mean        3.6  Female
# 995          Mean        2.8    Male

# %%
# Filter average number of unhealthy days by race in Texas
texas_race_df = race_df[race_df['State'] == 'Texas']
texas_race_df.head(10)
# Out:
#       Year  State                                           Question  \
# 1991  2011  Texas  Recent mentally unhealthy days among adults ag...
# 1992  2011  Texas  Recent mentally unhealthy days among adults ag...
# 1993  2011  Texas  Recent mentally unhealthy days among adults ag...
# 1994  2011  Texas  Recent mentally unhealthy days among adults ag...
# 1995  2011  Texas  Recent mentally unhealthy days among adults ag...
# 1996  2013  Texas  Recent mentally unhealthy days among adults ag...
# 1997  2013  Texas  Recent mentally unhealthy days among adults ag...
# 1998  2013  Texas  Recent mentally unhealthy days among adults ag...
# 1999  2013  Texas  Recent mentally unhealthy days among adults ag...
# 2000  2013  Texas  Recent mentally unhealthy days among adults ag...
#
#      DataValueType  DataValue             Race/Ethnicity
# 1991          Mean        3.9        Black, non-Hispanic
# 1992          Mean        3.6                   Hispanic
# 1993          Mean        8.0  Multiracial, non-Hispanic
# 1994          Mean        2.7        Other, non-Hispanic
# 1995          Mean        3.5        White, non-Hispanic
# 1996          Mean        4.3        Black, non-Hispanic
# 1997          Mean        3.0                   Hispanic
# 1998          Mean        5.1  Multiracial, non-Hispanic
# 1999          Mean        2.6        Other, non-Hispanic
# 2000          Mean        3.0        White, non-Hispanic

# %%
# Display average number of mentally unhealthy days by gender
# Filter df to only needed columns
filtered_gender_df = gender_df[['Year', 'DataValue', 'Gender']]

# Groupby year and gender, aggregate mean DataValue
grouped = filtered_gender_df.groupby(['Year', 'Gender'])['DataValue'].mean().unstack()

#Set color palette
colors = ['#ed4d5e', '#28a5c9']

# Plot bars 
fig, ax = plt.subplots()
grouped.plot(kind='bar', ax=ax, rot=0, color = colors ) 

ax.set_xlabel("Year")
ax.set_ylabel("Recent Mentally Unhealthy Days")
ax.legend(["Female", "Male"]);

fig.suptitle("Average Recent Mentally Unhealthy Days per Year");

plt.show()

# %%
# Display average number of mentally unhealthy days by gender in Texas
# Filter df to only needed columns
filtered_tx_df = texas_gender_df[['Year', 'DataValue', 'Gender']]

# Groupby year and gender, aggregate mean DataValue
grouped = filtered_tx_df.groupby(['Year', 'Gender'])['DataValue'].mean().unstack()

#Set color palette
colors = ['#ed4d5e', '#28a5c9']

# Plot bars 
fig, ax = plt.subplots()
grouped.plot(kind='bar', ax=ax, rot=0, color = colors) 

ax.set_xlabel("Year")
ax.set_ylabel("Recent Mentally Unhealthy Days")
ax.legend(["Female", "Male"]);

fig.suptitle("Average Recent Mentally Unhealthy Days per Year in Texas"); 

plt.show()

# %%
# Generate a pie plot showing the distribution of unhealthy days by gender
# Dataframe with gender and average unhealthy days 
pie_gender_df = gender_df.groupby('Gender')[['DataValue']].mean()

# Set color palette
colors = ['#ed4d5e', '#28a5c9']  

# Create pie chart
fig, ax = plt.subplots()
ax.pie(pie_gender_df['DataValue'], labels=pie_gender_df.index, colors=colors, autopct='%1.1f%%')
ax.axis('equal')

ax.set_title("Average  Recent Mentally Unhealthy Days by Gender (2011-2021)")
plt.tight_layout()
plt.show()

# %%
# Generate a pie plot showing the distribution of unhealthy days by gender in Texas
# Dataframe with gender and average unhealthy days 
tx_gender = texas_gender_df.groupby('Gender')[['DataValue']].mean()

# Set color palette
colors = ['#ed4d5e', '#28a5c9']  

# Create pie chart
fig, ax = plt.subplots()
ax.pie(tx_gender['DataValue'], labels=tx_gender.index, colors=colors, autopct='%1.1f%%')
ax.axis('equal')

ax.set_title("Average Recent Mentally Unhealthy Days by Gender in Texas (2011-2021)")
plt.tight_layout()
plt.show()

# %%
# Generate a stacked bar chart displaying average unhealthy days by race
# Filter dataframe 
filtered_race_df = race_df[['Year', 'DataValue', 'Race/Ethnicity']]

# Groupby year and race, aggregate mean DataValue
grouped = filtered_race_df.groupby(['Year', 'Race/Ethnicity'])['DataValue'].mean()  

# Unstack the Race/Ethnicity into columns
grouped = grouped.unstack()

# Plot stacked bars
ax = grouped.plot(kind='bar', stacked=True)

ax.set_xlabel('Year')
ax.set_ylabel('Recent Mentally Unhealthy Days')
ax.legend(bbox_to_anchor=(1.04,1)) 
plt.title('Average Recent Mentally Unhealthy Days by Race')

plt.show()

# %%
# Generate a pie plot showing the distribution of unhealthy days by race
# Group by race and aggregate mean  
pie_race_df = race_df.groupby('Race/Ethnicity')[['DataValue']].mean()

# Reset index to keep races as column 
pie_race_df = pie_race_df.reset_index() 

# Create pie chart
fig, ax = plt.subplots()
ax.pie(pie_race_df['DataValue'], labels=pie_race_df['Race/Ethnicity'], autopct='%1.1f%%')
ax.axis('equal')

ax.set_title("Average Recent Mentally Unhealthy Days by Race (2011-2021)") 

plt.show()
